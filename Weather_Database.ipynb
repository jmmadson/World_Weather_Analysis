# %%
# Import Dependancies
import random
import pandas as pd
import numpy as np
from citipy import citipy
from config import weather_api_key

# Import the requests library
import requests

# %%
# Create 2,000 random lat / lng

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-90.000, high=90.000, size=2000)
lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Get nearest City

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 747

# %%
# Perform an API call w/ OpenWeatherMap to retreive lat, lng, maxtemp, % humidity, % cloudiness, wind speed & description

# Starting URL for Weather Map API Call.
#url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial"

# Parse the JSON and retrieve data
#city_weather_url = url + "&q=rypefjord" "&appid=" + weather_api_key  

# city_weather = requests.get(city_weather_url).json()
#city_weather = requests.get(city_weather_url).json()

#city_weather

# %%
# Perform an API call w/ OpenWeatherMap to retreive lat, lng, maxtemp, % humidity, % cloudiness, wind speed & description

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial" 

# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
  
 # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+") +"&appid=" + weather_api_key

   # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
   

# Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                         "Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | lodwar
# Processing Record 2 of Set 1 | port alfred
# Processing Record 3 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 1 | dikson
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | san vicente de canete
# Processing Record 7 of Set 1 | natal
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | qaanaaq
# Processing Record 10 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 11 of Set 1 | bouar
# Processing Record 12 of Set 1 | thompson
# Processing Record 13 of Set 1 | cidreira
# Processing Record 14 of Set 1 | lagoa
# Processing Record 15 of Set 1 | bredasdorp
# Processing Record 16 of Set 1 | tukrah
# Processing Record 17 of Set 1 | karaul
# City not found. Skipping...
# Processing Record 18 of Set 1 | ajdabiya
# Processing Record 19 of Set 1 | hermanus
# Processing Record 20 of Set 1 | salalah
# Processing Record 21 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 22 of Set 1 | mehamn
# Processing Record 23 of Set 1 | arraial do cabo
# Processing Record 24 of Set 1 | beloha
# Processing Record 25 of Set 1 | buchanan
# Processing Record 26 of Set 1 | marsa matruh
# Processing Record 27 of Set 1 | cape town
# Processing Record 28 of Set 1 | camana
# Processing Record 29 of Set 1 | tasiilaq
# Processing Record 30 of Set 1 | tabou
# Processing Record 31 of Set 1 | chuy
# Processing Record 32 of Set 1 | klaksvik
# Processing Record 33 of Set 1 | buqayq
# City not found. Skipping...
# Processing Record 34 of Set 1 | sistranda
# Processing Record 35 of Set 1 | hearst
# Processing Record 36 of Set 1 | felanitx
# Processing Record 37 of Set 1 | khandbari
# Processing Record 38 of Set 1 | mahebourg
# Processing Record 39 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 40 of Set 1 | adrar
# Processing Record 41 of Set 1 | izhma
# Processing Record 42 of Set 1 | arroio grande
# Processing Record 43 of Set 1 | mrirt
# City not found. Skipping...
# Processing Record 44 of Set 1 | umm kaddadah
# Processing Record 45 of Set 1 | moyale
# Processing Record 46 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 47 of Set 1 | laguna
# Processing Record 48 of Set 1 | harlingen
# Processing Record 49 of Set 1 | boende
# Processing Record 50 of Set 1 | umm durman
# City not found. Skipping...
# Processing Record 1 of Set 2 | ponta do sol
# Processing Record 2 of Set 2 | cordoba
# Processing Record 3 of Set 2 | barcelos
# Processing Record 4 of Set 2 | souillac
# Processing Record 5 of Set 2 | ribeira grande
# Processing Record 6 of Set 2 | hambantota
# Processing Record 7 of Set 2 | burica
# City not found. Skipping...
# Processing Record 8 of Set 2 | bathsheba
# Processing Record 9 of Set 2 | oytal
# Processing Record 10 of Set 2 | savannah bight
# Processing Record 11 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 2 | abnub
# Processing Record 13 of Set 2 | jamestown
# Processing Record 14 of Set 2 | guatire
# Processing Record 15 of Set 2 | iturama
# Processing Record 16 of Set 2 | sisimiut
# Processing Record 17 of Set 2 | riaba
# City not found. Skipping...
# Processing Record 18 of Set 2 | saint-augustin
# Processing Record 19 of Set 2 | senneterre
# Processing Record 20 of Set 2 | cockburn town
# Processing Record 21 of Set 2 | miranda
# Processing Record 22 of Set 2 | hithadhoo
# Processing Record 23 of Set 2 | luderitz
# Processing Record 24 of Set 2 | brae
# Processing Record 25 of Set 2 | luena
# Processing Record 26 of Set 2 | portadown
# Processing Record 27 of Set 2 | lebu
# Processing Record 28 of Set 2 | maxixe
# Processing Record 29 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 2 | priiskovyy
# Processing Record 31 of Set 2 | rio gallegos
# Processing Record 32 of Set 2 | iracoubo
# Processing Record 33 of Set 2 | homa bay
# Processing Record 34 of Set 2 | oswego
# Processing Record 35 of Set 2 | henties bay
# Processing Record 36 of Set 2 | carnarvon
# Processing Record 37 of Set 2 | clyde river
# Processing Record 38 of Set 2 | baracoa
# Processing Record 39 of Set 2 | codrington
# Processing Record 40 of Set 2 | kaduqli
# Processing Record 41 of Set 2 | puerto madryn
# Processing Record 42 of Set 2 | ilulissat
# Processing Record 43 of Set 2 | bam
# Processing Record 44 of Set 2 | pangnirtung
# Processing Record 45 of Set 2 | sao jose da coroa grande
# Processing Record 46 of Set 2 | georgetown
# Processing Record 47 of Set 2 | ancud
# Processing Record 48 of Set 2 | cravo norte
# Processing Record 49 of Set 2 | upernavik
# Processing Record 50 of Set 2 | srisailam
# Processing Record 1 of Set 3 | jumla
# Processing Record 2 of Set 3 | koslan
# Processing Record 3 of Set 3 | nanortalik
# Processing Record 4 of Set 3 | yar-sale
# Processing Record 5 of Set 3 | trinidad
# Processing Record 6 of Set 3 | yerkoy
# Processing Record 7 of Set 3 | mar del plata
# Processing Record 8 of Set 3 | badnawar
# Processing Record 9 of Set 3 | sakakah
# Processing Record 10 of Set 3 | nara
# Processing Record 11 of Set 3 | paamiut
# Processing Record 12 of Set 3 | kariapatti
# Processing Record 13 of Set 3 | laon
# Processing Record 14 of Set 3 | pontes e lacerda
# Processing Record 15 of Set 3 | meulaboh
# Processing Record 16 of Set 3 | andenes
# Processing Record 17 of Set 3 | la arena
# Processing Record 18 of Set 3 | gore
# Processing Record 19 of Set 3 | abu samrah
# Processing Record 20 of Set 3 | saldanha
# Processing Record 21 of Set 3 | road town
# Processing Record 22 of Set 3 | itarema
# Processing Record 23 of Set 3 | longyearbyen
# Processing Record 24 of Set 3 | east london
# Processing Record 25 of Set 3 | penha
# Processing Record 26 of Set 3 | saint-philippe
# Processing Record 27 of Set 3 | dudinka
# Processing Record 28 of Set 3 | sao joao da barra
# Processing Record 29 of Set 3 | porto novo
# Processing Record 30 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 3 | lokoja
# Processing Record 32 of Set 3 | kibala
# Processing Record 33 of Set 3 | caravelas
# Processing Record 34 of Set 3 | arroyo
# Processing Record 35 of Set 3 | mogadishu
# Processing Record 36 of Set 3 | tinyahuarco
# Processing Record 37 of Set 3 | punta arenas
# Processing Record 38 of Set 3 | cherdyn
# Processing Record 39 of Set 3 | cabedelo
# Processing Record 40 of Set 3 | itaquaquecetuba
# Processing Record 41 of Set 3 | kuytun
# Processing Record 42 of Set 3 | pilar
# Processing Record 43 of Set 3 | namikupa
# Processing Record 44 of Set 3 | gueret
# Processing Record 45 of Set 3 | jiddah
# City not found. Skipping...
# Processing Record 46 of Set 3 | coihueco
# Processing Record 47 of Set 3 | marawi
# Processing Record 48 of Set 3 | hun
# Processing Record 49 of Set 3 | victoria
# Processing Record 50 of Set 3 | sao gabriel da cachoeira
# Processing Record 1 of Set 4 | bani walid
# Processing Record 2 of Set 4 | sao filipe
# Processing Record 3 of Set 4 | bom jesus
# Processing Record 4 of Set 4 | grand baie
# Processing Record 5 of Set 4 | awbari
# Processing Record 6 of Set 4 | torbay
# Processing Record 7 of Set 4 | port elizabeth
# Processing Record 8 of Set 4 | moramanga
# Processing Record 9 of Set 4 | coihaique
# Processing Record 10 of Set 4 | ponta delgada
# Processing Record 11 of Set 4 | artigas
# Processing Record 12 of Set 4 | takoradi
# Processing Record 13 of Set 4 | dinsor
# City not found. Skipping...
# Processing Record 14 of Set 4 | cavaillon
# Processing Record 15 of Set 4 | sarcelles
# Processing Record 16 of Set 4 | manakara
# Processing Record 17 of Set 4 | gat
# Processing Record 18 of Set 4 | huarmey
# Processing Record 19 of Set 4 | ngorongoro
# Processing Record 20 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 21 of Set 4 | grindavik
# Processing Record 22 of Set 4 | narsaq
# Processing Record 23 of Set 4 | cerignola
# Processing Record 24 of Set 4 | muisne
# Processing Record 25 of Set 4 | goderich
# Processing Record 26 of Set 4 | vila velha
# Processing Record 27 of Set 4 | xai-xai
# Processing Record 28 of Set 4 | ostrovnoy
# Processing Record 29 of Set 4 | ankola
# Processing Record 30 of Set 4 | tarudant
# City not found. Skipping...
# Processing Record 31 of Set 4 | arrifes
# Processing Record 32 of Set 4 | iquitos
# Processing Record 33 of Set 4 | amlagora
# Processing Record 34 of Set 4 | zyryanovskiy
# City not found. Skipping...
# Processing Record 35 of Set 4 | faya
# Processing Record 36 of Set 4 | severodvinsk
# Processing Record 37 of Set 4 | ambilobe
# Processing Record 38 of Set 4 | rawson
# Processing Record 39 of Set 4 | vysha
# Processing Record 40 of Set 4 | bambous virieux
# Processing Record 41 of Set 4 | naron
# Processing Record 42 of Set 4 | dingle
# Processing Record 43 of Set 4 | los llanos de aridane
# Processing Record 44 of Set 4 | tall kayf
# Processing Record 45 of Set 4 | khorixas
# Processing Record 46 of Set 4 | gamba
# Processing Record 47 of Set 4 | katima mulilo
# Processing Record 48 of Set 4 | nicoya
# Processing Record 49 of Set 4 | jalu
# Processing Record 50 of Set 4 | saint george
# Processing Record 1 of Set 5 | taoudenni
# Processing Record 2 of Set 5 | ardistan
# City not found. Skipping...
# Processing Record 3 of Set 5 | vardo
# Processing Record 4 of Set 5 | bajil
# Processing Record 5 of Set 5 | hamilton
# Processing Record 6 of Set 5 | synya
# Processing Record 7 of Set 5 | starokostyantyniv
# Processing Record 8 of Set 5 | pucallpa
# Processing Record 9 of Set 5 | xirokambion
# City not found. Skipping...
# Processing Record 10 of Set 5 | aksu
# Processing Record 11 of Set 5 | mmabatho
# Processing Record 12 of Set 5 | rioja
# Processing Record 13 of Set 5 | key largo
# Processing Record 14 of Set 5 | shu
# Processing Record 15 of Set 5 | rio grande
# Processing Record 16 of Set 5 | pandelys
# City not found. Skipping...
# Processing Record 17 of Set 5 | energetik
# Processing Record 18 of Set 5 | richards bay
# Processing Record 19 of Set 5 | san andres
# Processing Record 20 of Set 5 | sonipat
# Processing Record 21 of Set 5 | nikel
# Processing Record 22 of Set 5 | crab hill
# City not found. Skipping...
# Processing Record 23 of Set 5 | namibe
# Processing Record 24 of Set 5 | castro
# Processing Record 25 of Set 5 | qasigiannguit
# Processing Record 26 of Set 5 | brigantine
# Processing Record 27 of Set 5 | sosnovka
# Processing Record 28 of Set 5 | gravdal
# Processing Record 29 of Set 5 | kalmunai
# Processing Record 30 of Set 5 | ungheni
# Processing Record 31 of Set 5 | kharan
# Processing Record 32 of Set 5 | moose factory
# Processing Record 33 of Set 5 | ibotirama
# Processing Record 34 of Set 5 | soanierana ivongo
# Processing Record 35 of Set 5 | tarauaca
# Processing Record 36 of Set 5 | manaus
# Processing Record 37 of Set 5 | gangotri
# City not found. Skipping...
# Processing Record 38 of Set 5 | chinsali
# Processing Record 39 of Set 5 | inongo
# Processing Record 40 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 41 of Set 5 | mocambique
# City not found. Skipping...
# Processing Record 42 of Set 5 | zelenoborsk
# Processing Record 43 of Set 5 | starominskaya
# Processing Record 44 of Set 5 | pilao arcado
# City not found. Skipping...
# Processing Record 45 of Set 5 | karlshamn
# Processing Record 46 of Set 5 | taltal
# Processing Record 47 of Set 5 | kismayo
# Processing Record 48 of Set 5 | santa isabel do rio negro
# Processing Record 49 of Set 5 | sinnamary
# Processing Record 50 of Set 5 | albany
# Processing Record 1 of Set 6 | igrim
# Processing Record 2 of Set 6 | gubkinskiy
# Processing Record 3 of Set 6 | parry sound
# Processing Record 4 of Set 6 | najran
# Processing Record 5 of Set 6 | cumaribo
# City not found. Skipping...
# Processing Record 6 of Set 6 | punta alta
# Processing Record 7 of Set 6 | rydultowy
# Processing Record 8 of Set 6 | sorland
# Processing Record 9 of Set 6 | suceveni
# Processing Record 10 of Set 6 | prainha
# Processing Record 11 of Set 6 | sur
# Processing Record 12 of Set 6 | ordynskoye
# Processing Record 13 of Set 6 | tazovskiy
# Processing Record 14 of Set 6 | jibuti
# Processing Record 15 of Set 6 | cocobeach
# Processing Record 16 of Set 6 | fartura
# Processing Record 17 of Set 6 | kadrina
# Processing Record 18 of Set 6 | channel-port aux basques
# Processing Record 19 of Set 6 | salamanca
# Processing Record 20 of Set 6 | puerto colombia
# Processing Record 21 of Set 6 | santa cruz
# Processing Record 22 of Set 6 | bicholim
# Processing Record 23 of Set 6 | progreso
# Processing Record 24 of Set 6 | hofn
# Processing Record 25 of Set 6 | watsa
# Processing Record 26 of Set 6 | ntungamo
# Processing Record 27 of Set 6 | vila franca do campo
# Processing Record 28 of Set 6 | quixeramobim
# Processing Record 29 of Set 6 | bandarbeyla
# Processing Record 30 of Set 6 | kohlu
# Processing Record 31 of Set 6 | antofagasta
# Processing Record 32 of Set 6 | tullow
# Processing Record 33 of Set 6 | faro
# Processing Record 34 of Set 6 | quatre cocos
# Processing Record 35 of Set 6 | dhidhdhoo
# Processing Record 36 of Set 6 | sirjan
# Processing Record 37 of Set 6 | kosino
# Processing Record 38 of Set 6 | jiroft
# City not found. Skipping...
# Processing Record 39 of Set 6 | matiri
# Processing Record 40 of Set 6 | krasnoarmeyskoye
# Processing Record 41 of Set 6 | ciras
# City not found. Skipping...
# Processing Record 42 of Set 6 | chapada dos guimaraes
# Processing Record 43 of Set 6 | brikama
# Processing Record 44 of Set 6 | tashtyp
# Processing Record 45 of Set 6 | kruisfontein
# Processing Record 46 of Set 6 | maceio
# Processing Record 47 of Set 6 | somerset east
# Processing Record 48 of Set 6 | berbera
# Processing Record 49 of Set 6 | zachagansk
# City not found. Skipping...
# Processing Record 50 of Set 6 | vrutky
# Processing Record 1 of Set 7 | banki
# Processing Record 2 of Set 7 | belmonte
# Processing Record 3 of Set 7 | riberalta
# Processing Record 4 of Set 7 | soyo
# Processing Record 5 of Set 7 | manaskent
# Processing Record 6 of Set 7 | nashville
# Processing Record 7 of Set 7 | baherden
# Processing Record 8 of Set 7 | sabaudia
# Processing Record 9 of Set 7 | qaqortoq
# Processing Record 10 of Set 7 | nikki
# Processing Record 11 of Set 7 | diapaga
# Processing Record 12 of Set 7 | kokologo
# Processing Record 13 of Set 7 | macas
# Processing Record 14 of Set 7 | muravlenko
# Processing Record 15 of Set 7 | campo de criptana
# Processing Record 16 of Set 7 | parana
# Processing Record 17 of Set 7 | kerchevskiy
# Processing Record 18 of Set 7 | shakawe
# Processing Record 19 of Set 7 | alpena
# Processing Record 20 of Set 7 | dasoguz
# Processing Record 21 of Set 7 | atar
# Processing Record 22 of Set 7 | cheuskiny
# City not found. Skipping...
# Processing Record 23 of Set 7 | dangriga
# Processing Record 24 of Set 7 | uray
# Processing Record 25 of Set 7 | svetlyy
# Processing Record 26 of Set 7 | aras
# Processing Record 27 of Set 7 | porto velho
# Processing Record 28 of Set 7 | capinopolis
# Processing Record 29 of Set 7 | saint-leu
# Processing Record 30 of Set 7 | maksatikha
# Processing Record 31 of Set 7 | lukovetskiy
# Processing Record 32 of Set 7 | mossingen
# Processing Record 33 of Set 7 | ambanja
# Processing Record 34 of Set 7 | bubaque
# Processing Record 35 of Set 7 | turtas
# Processing Record 36 of Set 7 | olafsvik
# Processing Record 37 of Set 7 | bonavista
# Processing Record 38 of Set 7 | manadhoo
# Processing Record 39 of Set 7 | la rioja
# Processing Record 40 of Set 7 | aljezur
# Processing Record 41 of Set 7 | hoima
# Processing Record 42 of Set 7 | praia da vitoria
# Processing Record 43 of Set 7 | bilma
# Processing Record 44 of Set 7 | oranjemund
# Processing Record 45 of Set 7 | aragarcas
# Processing Record 46 of Set 7 | ciudad bolivar
# Processing Record 47 of Set 7 | chicama
# Processing Record 48 of Set 7 | palmas bellas
# Processing Record 49 of Set 7 | parabel
# Processing Record 50 of Set 7 | grand-santi
# Processing Record 1 of Set 8 | batticaloa
# Processing Record 2 of Set 8 | cayenne
# Processing Record 3 of Set 8 | oussouye
# Processing Record 4 of Set 8 | yokadouma
# Processing Record 5 of Set 8 | auray
# Processing Record 6 of Set 8 | harer
# Processing Record 7 of Set 8 | alta floresta
# Processing Record 8 of Set 8 | zajecar
# Processing Record 9 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 10 of Set 8 | jujuy
# City not found. Skipping...
# Processing Record 11 of Set 8 | korla
# Processing Record 12 of Set 8 | praia
# Processing Record 13 of Set 8 | cauquenes
# Processing Record 14 of Set 8 | kapoeta
# Processing Record 15 of Set 8 | guiratinga
# Processing Record 16 of Set 8 | salamiyah
# Processing Record 17 of Set 8 | roald
# Processing Record 18 of Set 8 | pervomayskoye
# Processing Record 19 of Set 8 | gweru
# Processing Record 20 of Set 8 | katsina
# Processing Record 21 of Set 8 | quelimane
# Processing Record 22 of Set 8 | marienburg
# Processing Record 23 of Set 8 | adre
# Processing Record 24 of Set 8 | velyka oleksandrivka
# Processing Record 25 of Set 8 | burevestnik
# Processing Record 26 of Set 8 | nauta
# Processing Record 27 of Set 8 | alcamo
# Processing Record 28 of Set 8 | glace bay
# Processing Record 29 of Set 8 | ereymentau
# Processing Record 30 of Set 8 | boa vista
# Processing Record 31 of Set 8 | puerto maldonado
# Processing Record 32 of Set 8 | kongolo
# Processing Record 33 of Set 8 | mitsamiouli
# Processing Record 34 of Set 8 | manta
# Processing Record 35 of Set 8 | berlevag
# Processing Record 36 of Set 8 | shelburne
# Processing Record 37 of Set 8 | de aar
# Processing Record 38 of Set 8 | tambopata
# Processing Record 39 of Set 8 | presidencia roque saenz pena
# Processing Record 40 of Set 8 | pell city
# Processing Record 41 of Set 8 | margate
# Processing Record 42 of Set 8 | landerneau
# Processing Record 43 of Set 8 | lida
# Processing Record 44 of Set 8 | sergeyevka
# Processing Record 45 of Set 8 | kavaratti
# Processing Record 46 of Set 8 | charleston
# Processing Record 47 of Set 8 | apeldoorn
# Processing Record 48 of Set 8 | grand gaube
# Processing Record 49 of Set 8 | curaca
# Processing Record 50 of Set 8 | yanam
# Processing Record 1 of Set 9 | millinocket
# Processing Record 2 of Set 9 | zhanaozen
# Processing Record 3 of Set 9 | thilogne
# City not found. Skipping...
# Processing Record 4 of Set 9 | zlitan
# Processing Record 5 of Set 9 | muros
# Processing Record 6 of Set 9 | sudak
# Processing Record 7 of Set 9 | endicott
# Processing Record 8 of Set 9 | gao
# Processing Record 9 of Set 9 | sokoni
# Processing Record 10 of Set 9 | shache
# Processing Record 11 of Set 9 | general roca
# Processing Record 12 of Set 9 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 13 of Set 9 | skjervoy
# Processing Record 14 of Set 9 | menongue
# Processing Record 15 of Set 9 | amersham
# Processing Record 16 of Set 9 | jacareacanga
# Processing Record 17 of Set 9 | vila do maio
# Processing Record 18 of Set 9 | paralimni
# Processing Record 19 of Set 9 | aparecida do taboado
# Processing Record 20 of Set 9 | lagos
# Processing Record 21 of Set 9 | lima
# Processing Record 22 of Set 9 | itaituba
# Processing Record 23 of Set 9 | gualaquiza
# Processing Record 24 of Set 9 | kagadi
# Processing Record 25 of Set 9 | staryy oskol
# Processing Record 26 of Set 9 | farafangana
# Processing Record 27 of Set 9 | saint-pierre
# Processing Record 28 of Set 9 | trelew
# Processing Record 29 of Set 9 | umba
# Processing Record 30 of Set 9 | coquimbo
# Processing Record 31 of Set 9 | massillon
# Processing Record 32 of Set 9 | ballstad
# City not found. Skipping...
# Processing Record 33 of Set 9 | sulurpeta
# City not found. Skipping...
# Processing Record 34 of Set 9 | ullapool
# Processing Record 35 of Set 9 | sao benedito do rio preto
# Processing Record 36 of Set 9 | joao pinheiro
# Processing Record 37 of Set 9 | mao
# Processing Record 38 of Set 9 | oranjestad
# Processing Record 39 of Set 9 | constitucion
# Processing Record 40 of Set 9 | el calvario
# Processing Record 41 of Set 9 | mumbwa
# Processing Record 42 of Set 9 | birjand
# Processing Record 43 of Set 9 | vetlanda
# Processing Record 44 of Set 9 | mahibadhoo
# Processing Record 45 of Set 9 | ordu
# Processing Record 46 of Set 9 | agirish
# Processing Record 47 of Set 9 | port-gentil
# Processing Record 48 of Set 9 | dagana
# Processing Record 49 of Set 9 | odweyne
# Processing Record 50 of Set 9 | pipri
# Processing Record 1 of Set 10 | inhambane
# Processing Record 2 of Set 10 | sumbe
# Processing Record 3 of Set 10 | ikom
# Processing Record 4 of Set 10 | plettenberg bay
# Processing Record 5 of Set 10 | iqaluit
# Processing Record 6 of Set 10 | uspenskaya
# Processing Record 7 of Set 10 | geraldton
# Processing Record 8 of Set 10 | matara
# Processing Record 9 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 10 of Set 10 | puerto el triunfo
# Processing Record 11 of Set 10 | shediac
# Processing Record 12 of Set 10 | sao roque
# Processing Record 13 of Set 10 | embonas
# Processing Record 14 of Set 10 | halifax
# Processing Record 15 of Set 10 | jijiga
# Processing Record 16 of Set 10 | ware
# Processing Record 17 of Set 10 | tshikapa
# Processing Record 18 of Set 10 | peniche
# Processing Record 19 of Set 10 | esmeraldas
# Processing Record 20 of Set 10 | abensberg
# Processing Record 21 of Set 10 | sangmelima
# Processing Record 22 of Set 10 | jiwani
# Processing Record 23 of Set 10 | marysville
# Processing Record 24 of Set 10 | dharchula
# Processing Record 25 of Set 10 | conceicao do araguaia
# Processing Record 26 of Set 10 | rodos
# Processing Record 27 of Set 10 | comodoro rivadavia
# Processing Record 28 of Set 10 | havelock
# Processing Record 29 of Set 10 | ciudad guayana
# Processing Record 30 of Set 10 | baboua
# City not found. Skipping...
# Processing Record 31 of Set 10 | sohag
# Processing Record 32 of Set 10 | killybegs
# Processing Record 33 of Set 10 | fandriana
# Processing Record 34 of Set 10 | fort-shevchenko
# Processing Record 35 of Set 10 | batsfjord
# Processing Record 36 of Set 10 | mudhol
# Processing Record 37 of Set 10 | cagliari
# Processing Record 38 of Set 10 | buncrana
# Processing Record 39 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 40 of Set 10 | beirut
# Processing Record 41 of Set 10 | bure
# Processing Record 42 of Set 10 | tres arroyos
# Processing Record 43 of Set 10 | sedelnikovo
# City not found. Skipping...
# Processing Record 44 of Set 10 | luquillo
# Processing Record 45 of Set 10 | dawlatabad
# Processing Record 46 of Set 10 | gari
# Processing Record 47 of Set 10 | dragotesti
# Processing Record 48 of Set 10 | dubenskiy
# City not found. Skipping...
# Processing Record 49 of Set 10 | santa ines
# Processing Record 50 of Set 10 | mount vernon
# Processing Record 1 of Set 11 | jaisalmer
# Processing Record 2 of Set 11 | gdansk
# Processing Record 3 of Set 11 | talcahuano
# Processing Record 4 of Set 11 | maniitsoq
# Processing Record 5 of Set 11 | kalevala
# Processing Record 6 of Set 11 | monrovia
# Processing Record 7 of Set 11 | kirkenaer
# Processing Record 8 of Set 11 | hamburg
# Processing Record 9 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 10 of Set 11 | okoneshnikovo
# Processing Record 11 of Set 11 | bulancak
# Processing Record 12 of Set 11 | cali
# Processing Record 13 of Set 11 | karlovo
# Processing Record 14 of Set 11 | tsienyane
# City not found. Skipping...
# Processing Record 15 of Set 11 | cassilandia
# Processing Record 16 of Set 11 | ardakan
# Processing Record 17 of Set 11 | karkaralinsk
# City not found. Skipping...
# Processing Record 18 of Set 11 | zvishavane
# Processing Record 19 of Set 11 | nantucket
# Processing Record 20 of Set 11 | resplendor
# Processing Record 21 of Set 11 | camopi
# Processing Record 22 of Set 11 | asyut
# Processing Record 23 of Set 11 | bombay
# Processing Record 24 of Set 11 | maues
# Processing Record 25 of Set 11 | qena
# Processing Record 26 of Set 11 | kargil
# Processing Record 27 of Set 11 | coro
# Processing Record 28 of Set 11 | benghazi
# Processing Record 29 of Set 11 | muzhi
# Processing Record 30 of Set 11 | villagomez
# Processing Record 31 of Set 11 | sucua
# Processing Record 32 of Set 11 | skuodas
# Processing Record 33 of Set 11 | harwich
# Processing Record 34 of Set 11 | buraydah
# Processing Record 35 of Set 11 | tangier
# Processing Record 36 of Set 11 | abu dhabi
# Processing Record 37 of Set 11 | radford
# Processing Record 38 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 39 of Set 11 | olinda
# Processing Record 40 of Set 11 | matadi
# Processing Record 41 of Set 11 | yarada
# Processing Record 42 of Set 11 | trosna
# Processing Record 43 of Set 11 | puerto narino
# Processing Record 44 of Set 11 | mancio lima
# Processing Record 45 of Set 11 | valparaiso
# Processing Record 46 of Set 11 | dianopolis
# City not found. Skipping...
# Processing Record 47 of Set 11 | saint-louis
# Processing Record 48 of Set 11 | chebsara
# Processing Record 49 of Set 11 | rabo de peixe
# Processing Record 50 of Set 11 | paraibano
# Processing Record 1 of Set 12 | igatpuri
# Processing Record 2 of Set 12 | eirunepe
# Processing Record 3 of Set 12 | necochea
# Processing Record 4 of Set 12 | urumqi
# Processing Record 5 of Set 12 | guaruja
# Processing Record 6 of Set 12 | omboue
# Processing Record 7 of Set 12 | rafaela
# Processing Record 8 of Set 12 | puerto leguizamo
# Processing Record 9 of Set 12 | imbituba
# Processing Record 10 of Set 12 | ginir
# Processing Record 11 of Set 12 | kant
# Processing Record 12 of Set 12 | kedrovyy
# Processing Record 13 of Set 12 | mpongwe
# Processing Record 14 of Set 12 | merritt island
# Processing Record 15 of Set 12 | kalangala
# Processing Record 16 of Set 12 | sioux lookout
# Processing Record 17 of Set 12 | sembe
# Processing Record 18 of Set 12 | nouakchott
# Processing Record 19 of Set 12 | bartica
# Processing Record 20 of Set 12 | fez
# Processing Record 21 of Set 12 | el carmen
# Processing Record 22 of Set 12 | termoli
# Processing Record 23 of Set 12 | wahran
# City not found. Skipping...
# Processing Record 24 of Set 12 | salta
# Processing Record 25 of Set 12 | oktyabrskoye
# Processing Record 26 of Set 12 | bordighera
# Processing Record 27 of Set 12 | vestmannaeyjar
# Processing Record 28 of Set 12 | ituni
# City not found. Skipping...
# Processing Record 29 of Set 12 | rabak
# Processing Record 30 of Set 12 | matay
# Processing Record 31 of Set 12 | syracuse
# Processing Record 32 of Set 12 | minab
# Processing Record 33 of Set 12 | impfondo
# Processing Record 34 of Set 12 | bengkulu
# Processing Record 35 of Set 12 | gilgit
# Processing Record 36 of Set 12 | tocopilla
# Processing Record 37 of Set 12 | carutapera
# Processing Record 38 of Set 12 | botucatu
# Processing Record 39 of Set 12 | mbandaka
# Processing Record 40 of Set 12 | pleasantville
# Processing Record 41 of Set 12 | luba
# Processing Record 42 of Set 12 | lokhvytsya
# Processing Record 43 of Set 12 | zamora
# Processing Record 44 of Set 12 | arkhangelos
# City not found. Skipping...
# Processing Record 45 of Set 12 | tucurui
# Processing Record 46 of Set 12 | lamu
# Processing Record 47 of Set 12 | barra do garcas
# Processing Record 48 of Set 12 | westport
# Processing Record 49 of Set 12 | ushtobe
# Processing Record 50 of Set 12 | qabis
# City not found. Skipping...
# Processing Record 1 of Set 13 | uaua
# Processing Record 2 of Set 13 | kutum
# Processing Record 3 of Set 13 | mahadday weyne
# City not found. Skipping...
# Processing Record 4 of Set 13 | asfi
# Processing Record 5 of Set 13 | touros
# Processing Record 6 of Set 13 | jubayl
# City not found. Skipping...
# Processing Record 7 of Set 13 | sechura
# Processing Record 8 of Set 13 | antalaha
# Processing Record 9 of Set 13 | port-cartier
# Processing Record 10 of Set 13 | pavlodar
# Processing Record 11 of Set 13 | kirovskiy
# Processing Record 12 of Set 13 | batamshinskiy
# Processing Record 13 of Set 13 | tapes
# Processing Record 14 of Set 13 | santa teresa
# Processing Record 15 of Set 13 | rio cuarto
# Processing Record 16 of Set 13 | tahta
# Processing Record 17 of Set 13 | hilsa
# Processing Record 18 of Set 13 | rundu
# Processing Record 19 of Set 13 | pfaffikon
# Processing Record 20 of Set 13 | soure
# Processing Record 21 of Set 13 | tacoronte
# Processing Record 22 of Set 13 | havoysund
# Processing Record 23 of Set 13 | kalutara
# Processing Record 24 of Set 13 | revda
# Processing Record 25 of Set 13 | nadym
# Processing Record 26 of Set 13 | plouzane
# Processing Record 27 of Set 13 | agsu
# City not found. Skipping...
# Processing Record 28 of Set 13 | trairi
# Processing Record 29 of Set 13 | mafeteng
# Processing Record 30 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 31 of Set 13 | beli potok
# Processing Record 32 of Set 13 | kalety
# Processing Record 33 of Set 13 | prieska
# Processing Record 34 of Set 13 | sol-iletsk
# Processing Record 35 of Set 13 | stokmarknes
# Processing Record 36 of Set 13 | nalut
# Processing Record 37 of Set 13 | selma
# Processing Record 38 of Set 13 | ailigandi
# Processing Record 39 of Set 13 | camacha
# Processing Record 40 of Set 13 | dukstas
# Processing Record 41 of Set 13 | sekoma
# Processing Record 42 of Set 13 | loiza
# Processing Record 43 of Set 13 | butterworth
# Processing Record 44 of Set 13 | desaguadero
# Processing Record 45 of Set 13 | kholm
# Processing Record 46 of Set 13 | garango
# Processing Record 47 of Set 13 | hualmay
# Processing Record 48 of Set 13 | kinanah
# City not found. Skipping...
# Processing Record 49 of Set 13 | cabinda
# Processing Record 50 of Set 13 | clarksburg
# Processing Record 1 of Set 14 | kargasok
# Processing Record 2 of Set 14 | bougouni
# Processing Record 3 of Set 14 | doha
# Processing Record 4 of Set 14 | yirol
# City not found. Skipping...
# Processing Record 5 of Set 14 | chateaubelair
# Processing Record 6 of Set 14 | makinsk
# Processing Record 7 of Set 14 | vallenar
# Processing Record 8 of Set 14 | boueni
# Processing Record 9 of Set 14 | reyes
# Processing Record 10 of Set 14 | mizdah
# Processing Record 11 of Set 14 | ocean city
# Processing Record 12 of Set 14 | altoona
# Processing Record 13 of Set 14 | marseille
# Processing Record 14 of Set 14 | san cristobal
# Processing Record 15 of Set 14 | hobyo
# Processing Record 16 of Set 14 | barranca
# Processing Record 17 of Set 14 | oum hadjer
# Processing Record 18 of Set 14 | kars
# Processing Record 19 of Set 14 | honningsvag
# Processing Record 20 of Set 14 | shirvan
# Processing Record 21 of Set 14 | kostomuksha
# Processing Record 22 of Set 14 | athmallik
# Processing Record 23 of Set 14 | yukamenskoye
# Processing Record 24 of Set 14 | santana do livramento
# Processing Record 25 of Set 14 | cazzago san martino
# Processing Record 26 of Set 14 | mwinilunga
# Processing Record 27 of Set 14 | san alberto
# Processing Record 28 of Set 14 | tashtagol
# Processing Record 29 of Set 14 | lourdes
# Processing Record 30 of Set 14 | ibra
# Processing Record 31 of Set 14 | narasaraopet
# Processing Record 32 of Set 14 | paita
# Processing Record 33 of Set 14 | yimnon
# Processing Record 34 of Set 14 | gazli
# Processing Record 35 of Set 14 | orbetello
# Processing Record 36 of Set 14 | tessalit
# Processing Record 37 of Set 14 | kashi
# Processing Record 38 of Set 14 | hetauda
# Processing Record 39 of Set 14 | uarini
# Processing Record 40 of Set 14 | axim
# Processing Record 41 of Set 14 | oistins
# Processing Record 42 of Set 14 | dalvik
# Processing Record 43 of Set 14 | eyl
# Processing Record 44 of Set 14 | rulenge
# Processing Record 45 of Set 14 | sault sainte marie
# Processing Record 46 of Set 14 | saint-francois
# Processing Record 47 of Set 14 | nizip
# Processing Record 48 of Set 14 | west point
# Processing Record 49 of Set 14 | temiscaming
# Processing Record 50 of Set 14 | inhumas
# Processing Record 1 of Set 15 | shubarshi
# Processing Record 2 of Set 15 | x-can
# City not found. Skipping...
# Processing Record 3 of Set 15 | sal rei
# Processing Record 4 of Set 15 | terre haute
# Processing Record 5 of Set 15 | moussoro
# Processing Record 6 of Set 15 | handwara
# City not found. Skipping...
# Processing Record 7 of Set 15 | floro
# Processing Record 8 of Set 15 | maldonado
# Processing Record 9 of Set 15 | husavik
# Processing Record 10 of Set 15 | murshidabad
# Processing Record 11 of Set 15 | stralsund
# Processing Record 12 of Set 15 | skelleftea
# Processing Record 13 of Set 15 | krasnoye
# Processing Record 14 of Set 15 | mana
# Processing Record 15 of Set 15 | mattawa
# Processing Record 16 of Set 15 | marzuq
# Processing Record 17 of Set 15 | vuktyl
# Processing Record 18 of Set 15 | wadi musa
# Processing Record 19 of Set 15 | san carlos de bariloche
# Processing Record 20 of Set 15 | kandi
# Processing Record 21 of Set 15 | aswan
# Processing Record 22 of Set 15 | umea
# Processing Record 23 of Set 15 | kibondo
# Processing Record 24 of Set 15 | tarata
# Processing Record 25 of Set 15 | binika
# Processing Record 26 of Set 15 | eganville
# Processing Record 27 of Set 15 | oparino
# Processing Record 28 of Set 15 | utete
# Processing Record 29 of Set 15 | bognor regis
# Processing Record 30 of Set 15 | mouila
# Processing Record 31 of Set 15 | pustoshka
# Processing Record 32 of Set 15 | chapais
# Processing Record 33 of Set 15 | strezhevoy
# Processing Record 34 of Set 15 | zenzeli
# Processing Record 35 of Set 15 | nynashamn
# Processing Record 36 of Set 15 | el prat de llobregat
# Processing Record 37 of Set 15 | varkkallai
# Processing Record 38 of Set 15 | kyabe
# Processing Record 39 of Set 15 | narasannapeta
# Processing Record 40 of Set 15 | mercedes
# Processing Record 41 of Set 15 | coria
# Processing Record 42 of Set 15 | yellamanchili
# City not found. Skipping...
# Processing Record 43 of Set 15 | layou
# Processing Record 44 of Set 15 | uspenka
# Processing Record 45 of Set 15 | wasaga beach
# Processing Record 46 of Set 15 | mabaruma
# Processing Record 47 of Set 15 | diekirch
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add data to a new dataframe
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                     City Country      Lat       Lng  Max Temp  Humidity  \
# 0                 Lodwar      KE   3.1191   35.5973     84.25        42
# 1            Port Alfred      ZA -33.5906   26.8910     60.40        63
# 2                 Dikson      RU  73.5069   80.5464      8.06        87
# 3                Ushuaia      AR -54.8000  -68.3000     33.46        93
# 4  San Vicente De Canete      PE -13.0751  -76.3835     65.28        77
# 5                  Natal      BR  -5.7950  -35.2094     81.25        78
# 6              Busselton      AU -33.6500  115.3333     50.09        77
# 7                Qaanaaq      GL  77.4840  -69.3632     -1.44        58
# 8                  Bouar      CF   5.9340   15.5960     64.13        94
# 9               Thompson      CA  55.7435  -97.8558     37.33        73
#
#    Cloudiness  Wind Speed      Description
# 0          15       10.40       few clouds
# 1           2       18.81        clear sky
# 2          99       11.90  overcast clouds
# 3          75       18.41             snow
# 4          19        8.05       few clouds
# 5          20       17.27       few clouds
# 6          92        4.70  overcast clouds
# 7           0        8.63        clear sky
# 8           9        3.71        clear sky
# 9         100        3.15  overcast clouds

# %%
# Export the DataFr# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"

#Export the City_data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
