# %%
# Import Dependancies
import random
import pandas as pd
import numpy as np
from citipy import citipy
from config import weather_api_key

# Import the requests library
import requests

# %%
# Create 2,000 random lat / lng

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-90.000, high=90.000, size=2000)
lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Get nearest City

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 742

# %%
# Perform an API call w/ OpenWeatherMap to retreive lat, lng, maxtemp, % humidity, % cloudiness, wind speed & description

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial" 

# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
  
 # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+") +"&appid=" + weather_api_key

   # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
   

 # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cape town
# Processing Record 2 of Set 1 | qaqortoq
# Processing Record 3 of Set 1 | iqaluit
# Processing Record 4 of Set 1 | hermanus
# Processing Record 5 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 6 of Set 1 | port alfred
# Processing Record 7 of Set 1 | sakakah
# Processing Record 8 of Set 1 | saint-philippe
# Processing Record 9 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 1 | santa isabel do rio negro
# Processing Record 11 of Set 1 | coquimbo
# Processing Record 12 of Set 1 | kurbnesh
# Processing Record 13 of Set 1 | lebu
# Processing Record 14 of Set 1 | ghatanji
# Processing Record 15 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 1 | marathon
# Processing Record 17 of Set 1 | kiruna
# Processing Record 18 of Set 1 | hithadhoo
# Processing Record 19 of Set 1 | oum hadjer
# Processing Record 20 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 1 | fraserburgh
# Processing Record 22 of Set 1 | ilulissat
# Processing Record 23 of Set 1 | tome-acu
# City not found. Skipping...
# Processing Record 24 of Set 1 | dikson
# Processing Record 25 of Set 1 | vardo
# Processing Record 26 of Set 1 | maghama
# City not found. Skipping...
# Processing Record 27 of Set 1 | lithakia
# Processing Record 28 of Set 1 | kumo
# Processing Record 29 of Set 1 | sistranda
# Processing Record 30 of Set 1 | kurgan
# Processing Record 31 of Set 1 | bambous virieux
# Processing Record 32 of Set 1 | caceres
# Processing Record 33 of Set 1 | ushuaia
# Processing Record 34 of Set 1 | busselton
# Processing Record 35 of Set 1 | dabat
# Processing Record 36 of Set 1 | qaanaaq
# Processing Record 37 of Set 1 | ponta do sol
# Processing Record 38 of Set 1 | padang
# Processing Record 39 of Set 1 | guliston
# Processing Record 40 of Set 1 | husavik
# Processing Record 41 of Set 1 | bakreswar
# Processing Record 42 of Set 1 | vila franca do campo
# Processing Record 43 of Set 1 | coro
# Processing Record 44 of Set 1 | mayachnyy
# Processing Record 45 of Set 1 | arnold
# Processing Record 46 of Set 1 | ongandjera
# Processing Record 47 of Set 1 | tyulyachi
# Processing Record 48 of Set 1 | huntsville
# Processing Record 49 of Set 1 | bouar
# Processing Record 50 of Set 1 | mullaitivu
# City not found. Skipping...
# Processing Record 1 of Set 2 | yabrud
# Processing Record 2 of Set 2 | kochki
# Processing Record 3 of Set 2 | bredasdorp
# Processing Record 4 of Set 2 | bubaque
# Processing Record 5 of Set 2 | sao filipe
# Processing Record 6 of Set 2 | shakiso
# Processing Record 7 of Set 2 | olafsvik
# Processing Record 8 of Set 2 | ribeira grande
# Processing Record 9 of Set 2 | souillac
# Processing Record 10 of Set 2 | jamestown
# Processing Record 11 of Set 2 | victoria
# Processing Record 12 of Set 2 | necochea
# Processing Record 13 of Set 2 | trairi
# Processing Record 14 of Set 2 | lardos
# Processing Record 15 of Set 2 | taltal
# Processing Record 16 of Set 2 | stornoway
# Processing Record 17 of Set 2 | mumbwa
# Processing Record 18 of Set 2 | zhezkazgan
# Processing Record 19 of Set 2 | abu samrah
# Processing Record 20 of Set 2 | sur
# Processing Record 21 of Set 2 | san cristobal
# Processing Record 22 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 2 | guanica
# Processing Record 24 of Set 2 | chicama
# Processing Record 25 of Set 2 | camana
# Processing Record 26 of Set 2 | puerto del rosario
# Processing Record 27 of Set 2 | oktyabrskoye
# Processing Record 28 of Set 2 | uusikaupunki
# Processing Record 29 of Set 2 | mar del plata
# Processing Record 30 of Set 2 | east london
# Processing Record 31 of Set 2 | frunzivka
# Processing Record 32 of Set 2 | salalah
# Processing Record 33 of Set 2 | paso de carrasco
# Processing Record 34 of Set 2 | maroantsetra
# Processing Record 35 of Set 2 | port elizabeth
# Processing Record 36 of Set 2 | yarada
# Processing Record 37 of Set 2 | adeje
# Processing Record 38 of Set 2 | riyadh
# Processing Record 39 of Set 2 | omutinskoye
# City not found. Skipping...
# Processing Record 40 of Set 2 | wamba
# Processing Record 41 of Set 2 | hualmay
# Processing Record 42 of Set 2 | clyde river
# Processing Record 43 of Set 2 | dalbandin
# Processing Record 44 of Set 2 | ostrovnoy
# Processing Record 45 of Set 2 | kalmunai
# Processing Record 46 of Set 2 | warrington
# Processing Record 47 of Set 2 | samur
# Processing Record 48 of Set 2 | kolo
# Processing Record 49 of Set 2 | calabozo
# Processing Record 50 of Set 2 | plettenberg bay
# Processing Record 1 of Set 3 | lethem
# Processing Record 2 of Set 3 | kulhudhuffushi
# Processing Record 3 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 3 | locri
# Processing Record 5 of Set 3 | kipushi
# Processing Record 6 of Set 3 | geraldton
# Processing Record 7 of Set 3 | paradwip
# City not found. Skipping...
# Processing Record 8 of Set 3 | dutlwe
# Processing Record 9 of Set 3 | cayenne
# Processing Record 10 of Set 3 | yar-sale
# Processing Record 11 of Set 3 | margate
# Processing Record 12 of Set 3 | gazalkent
# Processing Record 13 of Set 3 | punta arenas
# Processing Record 14 of Set 3 | kutahya
# Processing Record 15 of Set 3 | kargopol
# Processing Record 16 of Set 3 | say
# Processing Record 17 of Set 3 | marsa matruh
# Processing Record 18 of Set 3 | nanortalik
# Processing Record 19 of Set 3 | tapes
# Processing Record 20 of Set 3 | kyshtovka
# Processing Record 21 of Set 3 | arraial do cabo
# Processing Record 22 of Set 3 | aquiraz
# Processing Record 23 of Set 3 | longyearbyen
# Processing Record 24 of Set 3 | santa margherita ligure
# Processing Record 25 of Set 3 | havelock
# Processing Record 26 of Set 3 | manta
# Processing Record 27 of Set 3 | muisne
# Processing Record 28 of Set 3 | mao
# Processing Record 29 of Set 3 | gandajika
# Processing Record 30 of Set 3 | bossangoa
# Processing Record 31 of Set 3 | areia branca
# Processing Record 32 of Set 3 | bonavista
# Processing Record 33 of Set 3 | santander
# Processing Record 34 of Set 3 | tasiilaq
# Processing Record 35 of Set 3 | scottsburgh
# City not found. Skipping...
# Processing Record 36 of Set 3 | mutuipe
# Processing Record 37 of Set 3 | codrington
# Processing Record 38 of Set 3 | bonthe
# Processing Record 39 of Set 3 | khandbari
# Processing Record 40 of Set 3 | pyaozerskiy
# Processing Record 41 of Set 3 | gat
# Processing Record 42 of Set 3 | hare bay
# Processing Record 43 of Set 3 | ambovombe
# Processing Record 44 of Set 3 | senanga
# Processing Record 45 of Set 3 | mahebourg
# Processing Record 46 of Set 3 | paamiut
# Processing Record 47 of Set 3 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 48 of Set 3 | xudat
# Processing Record 49 of Set 3 | iquitos
# Processing Record 50 of Set 3 | acarau
# Processing Record 1 of Set 4 | mali
# Processing Record 2 of Set 4 | carlisle
# Processing Record 3 of Set 4 | manono
# Processing Record 4 of Set 4 | mocuba
# Processing Record 5 of Set 4 | hambantota
# Processing Record 6 of Set 4 | sayyan
# Processing Record 7 of Set 4 | lima
# Processing Record 8 of Set 4 | quelimane
# Processing Record 9 of Set 4 | camalote
# Processing Record 10 of Set 4 | caravelas
# Processing Record 11 of Set 4 | kavaratti
# Processing Record 12 of Set 4 | torbay
# Processing Record 13 of Set 4 | coihaique
# Processing Record 14 of Set 4 | thompson
# Processing Record 15 of Set 4 | vytegra
# Processing Record 16 of Set 4 | saint-augustin
# Processing Record 17 of Set 4 | beloha
# Processing Record 18 of Set 4 | kurdzhinovo
# Processing Record 19 of Set 4 | upernavik
# Processing Record 20 of Set 4 | cidreira
# Processing Record 21 of Set 4 | mudyuga
# City not found. Skipping...
# Processing Record 22 of Set 4 | skjervoy
# Processing Record 23 of Set 4 | kanye
# Processing Record 24 of Set 4 | nouadhibou
# Processing Record 25 of Set 4 | sisimiut
# Processing Record 26 of Set 4 | selcuk
# Processing Record 27 of Set 4 | saint george
# Processing Record 28 of Set 4 | georgetown
# Processing Record 29 of Set 4 | santa vitoria do palmar
# Processing Record 30 of Set 4 | boende
# Processing Record 31 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 32 of Set 4 | kargasok
# Processing Record 33 of Set 4 | general roca
# Processing Record 34 of Set 4 | manbij
# Processing Record 35 of Set 4 | okahandja
# Processing Record 36 of Set 4 | nirmali
# Processing Record 37 of Set 4 | rio grande
# Processing Record 38 of Set 4 | san jeronimo de tunan
# City not found. Skipping...
# Processing Record 39 of Set 4 | strezhevoy
# Processing Record 40 of Set 4 | xuddur
# Processing Record 41 of Set 4 | olinda
# Processing Record 42 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 4 | berlevag
# Processing Record 44 of Set 4 | talnakh
# Processing Record 45 of Set 4 | sorland
# Processing Record 46 of Set 4 | albina
# Processing Record 47 of Set 4 | balykshi
# Processing Record 48 of Set 4 | zlobin
# Processing Record 49 of Set 4 | chebsara
# Processing Record 50 of Set 4 | thiruvananthapuram
# Processing Record 1 of Set 5 | meulaboh
# Processing Record 2 of Set 5 | sumbe
# Processing Record 3 of Set 5 | arcozelo
# Processing Record 4 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 5 | diffa
# Processing Record 6 of Set 5 | augusta
# Processing Record 7 of Set 5 | kita
# Processing Record 8 of Set 5 | tubruq
# City not found. Skipping...
# Processing Record 9 of Set 5 | buraydah
# Processing Record 10 of Set 5 | malpe
# Processing Record 11 of Set 5 | guider
# Processing Record 12 of Set 5 | mantua
# Processing Record 13 of Set 5 | verkhniy lomov
# Processing Record 14 of Set 5 | yelahanka
# Processing Record 15 of Set 5 | henties bay
# Processing Record 16 of Set 5 | havoysund
# Processing Record 17 of Set 5 | barcelos
# Processing Record 18 of Set 5 | namibe
# Processing Record 19 of Set 5 | yirol
# City not found. Skipping...
# Processing Record 20 of Set 5 | saldanha
# Processing Record 21 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 5 | tarudant
# City not found. Skipping...
# Processing Record 23 of Set 5 | chapais
# Processing Record 24 of Set 5 | westport
# Processing Record 25 of Set 5 | malwan
# City not found. Skipping...
# Processing Record 26 of Set 5 | pucara
# Processing Record 27 of Set 5 | poltavka
# Processing Record 28 of Set 5 | bud
# Processing Record 29 of Set 5 | sao desiderio
# Processing Record 30 of Set 5 | randfontein
# Processing Record 31 of Set 5 | nizwa
# Processing Record 32 of Set 5 | hamilton
# Processing Record 33 of Set 5 | placido de castro
# Processing Record 34 of Set 5 | klaksvik
# Processing Record 35 of Set 5 | kvam
# Processing Record 36 of Set 5 | richards bay
# Processing Record 37 of Set 5 | general pico
# Processing Record 38 of Set 5 | krasnoselkup
# Processing Record 39 of Set 5 | buchanan
# Processing Record 40 of Set 5 | pucallpa
# Processing Record 41 of Set 5 | la rioja
# Processing Record 42 of Set 5 | vila velha
# Processing Record 43 of Set 5 | batsfjord
# Processing Record 44 of Set 5 | aksarka
# Processing Record 45 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 46 of Set 5 | sinop
# Processing Record 47 of Set 5 | cuenca
# Processing Record 48 of Set 5 | inirida
# Processing Record 49 of Set 5 | anta
# Processing Record 50 of Set 5 | matadi
# Processing Record 1 of Set 6 | carnarvon
# Processing Record 2 of Set 6 | svetlyy
# Processing Record 3 of Set 6 | thunder bay
# Processing Record 4 of Set 6 | beyneu
# Processing Record 5 of Set 6 | muros
# Processing Record 6 of Set 6 | atyrau
# Processing Record 7 of Set 6 | carupano
# Processing Record 8 of Set 6 | naryan-mar
# Processing Record 9 of Set 6 | limon
# Processing Record 10 of Set 6 | lagoa
# Processing Record 11 of Set 6 | sao joao da barra
# Processing Record 12 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 13 of Set 6 | san carlos de bariloche
# Processing Record 14 of Set 6 | arrecife
# Processing Record 15 of Set 6 | iranshahr
# Processing Record 16 of Set 6 | atar
# Processing Record 17 of Set 6 | miasskoye
# Processing Record 18 of Set 6 | cockburn town
# Processing Record 19 of Set 6 | ritchie
# Processing Record 20 of Set 6 | kangaatsiaq
# Processing Record 21 of Set 6 | manadhoo
# Processing Record 22 of Set 6 | shache
# Processing Record 23 of Set 6 | saint-georges
# Processing Record 24 of Set 6 | ancud
# Processing Record 25 of Set 6 | lodja
# Processing Record 26 of Set 6 | luderitz
# Processing Record 27 of Set 6 | touros
# Processing Record 28 of Set 6 | maragogi
# Processing Record 29 of Set 6 | soyo
# Processing Record 30 of Set 6 | kamenka
# Processing Record 31 of Set 6 | dole
# Processing Record 32 of Set 6 | campos belos
# Processing Record 33 of Set 6 | miandrivazo
# Processing Record 34 of Set 6 | dinguiraye
# Processing Record 35 of Set 6 | salinopolis
# Processing Record 36 of Set 6 | umtata
# Processing Record 37 of Set 6 | turukhansk
# Processing Record 38 of Set 6 | huarmey
# Processing Record 39 of Set 6 | arlit
# Processing Record 40 of Set 6 | saint-marc-des-carrieres
# Processing Record 41 of Set 6 | tornio
# Processing Record 42 of Set 6 | afmadu
# City not found. Skipping...
# Processing Record 43 of Set 6 | saint-pierre
# Processing Record 44 of Set 6 | portel
# Processing Record 45 of Set 6 | morshansk
# Processing Record 46 of Set 6 | avsyunino
# Processing Record 47 of Set 6 | mitsamiouli
# Processing Record 48 of Set 6 | salinas
# Processing Record 49 of Set 6 | srivardhan
# Processing Record 50 of Set 6 | hofn
# Processing Record 1 of Set 7 | grindavik
# Processing Record 2 of Set 7 | sechura
# Processing Record 3 of Set 7 | puri
# Processing Record 4 of Set 7 | mattru
# Processing Record 5 of Set 7 | hwange
# Processing Record 6 of Set 7 | gainesville
# Processing Record 7 of Set 7 | bengkulu
# Processing Record 8 of Set 7 | cabedelo
# Processing Record 9 of Set 7 | amalapuram
# Processing Record 10 of Set 7 | khorixas
# Processing Record 11 of Set 7 | bathsheba
# Processing Record 12 of Set 7 | resistencia
# Processing Record 13 of Set 7 | qarqin
# Processing Record 14 of Set 7 | castro
# Processing Record 15 of Set 7 | goundam
# Processing Record 16 of Set 7 | agadir
# Processing Record 17 of Set 7 | ventspils
# Processing Record 18 of Set 7 | gravdal
# Processing Record 19 of Set 7 | bandarbeyla
# Processing Record 20 of Set 7 | stantsiya gorchakovo
# City not found. Skipping...
# Processing Record 21 of Set 7 | venice
# Processing Record 22 of Set 7 | verkhnyaya inta
# Processing Record 23 of Set 7 | sahrak
# City not found. Skipping...
# Processing Record 24 of Set 7 | carutapera
# Processing Record 25 of Set 7 | altay
# Processing Record 26 of Set 7 | marienburg
# Processing Record 27 of Set 7 | dogondoutchi
# Processing Record 28 of Set 7 | ubinskoye
# Processing Record 29 of Set 7 | kalundborg
# Processing Record 30 of Set 7 | quatre cocos
# Processing Record 31 of Set 7 | pisco
# Processing Record 32 of Set 7 | cockburn harbour
# City not found. Skipping...
# Processing Record 33 of Set 7 | aizkraukle
# Processing Record 34 of Set 7 | totness
# Processing Record 35 of Set 7 | untsukul
# Processing Record 36 of Set 7 | tabuk
# Processing Record 37 of Set 7 | herat
# Processing Record 38 of Set 7 | saint anthony
# Processing Record 39 of Set 7 | maholi
# Processing Record 40 of Set 7 | musoma
# Processing Record 41 of Set 7 | parana
# Processing Record 42 of Set 7 | narsaq
# Processing Record 43 of Set 7 | dwarka
# Processing Record 44 of Set 7 | maniitsoq
# Processing Record 45 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 46 of Set 7 | gornopravdinsk
# Processing Record 47 of Set 7 | prado
# Processing Record 48 of Set 7 | novyy urengoy
# Processing Record 49 of Set 7 | vestmannaeyjar
# Processing Record 50 of Set 7 | urubicha
# Processing Record 1 of Set 8 | krapivinskiy
# Processing Record 2 of Set 8 | chuy
# Processing Record 3 of Set 8 | ilfracombe
# Processing Record 4 of Set 8 | mocambique
# City not found. Skipping...
# Processing Record 5 of Set 8 | santa fe
# Processing Record 6 of Set 8 | shubarshi
# Processing Record 7 of Set 8 | shchigry
# Processing Record 8 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 9 of Set 8 | leeuwarden
# Processing Record 10 of Set 8 | soyaux
# Processing Record 11 of Set 8 | valdivia
# Processing Record 12 of Set 8 | faya
# Processing Record 13 of Set 8 | sikeston
# Processing Record 14 of Set 8 | vikulovo
# Processing Record 15 of Set 8 | isilkul
# Processing Record 16 of Set 8 | pimenta bueno
# Processing Record 17 of Set 8 | khvorostyanka
# Processing Record 18 of Set 8 | crotone
# Processing Record 19 of Set 8 | dataganj
# Processing Record 20 of Set 8 | fonte boa
# Processing Record 21 of Set 8 | achisay
# City not found. Skipping...
# Processing Record 22 of Set 8 | pombas
# Processing Record 23 of Set 8 | karakose
# City not found. Skipping...
# Processing Record 24 of Set 8 | tazmalt
# Processing Record 25 of Set 8 | adrar
# Processing Record 26 of Set 8 | micheweni
# Processing Record 27 of Set 8 | mathathane
# Processing Record 28 of Set 8 | jedrzejow
# Processing Record 29 of Set 8 | umm lajj
# Processing Record 30 of Set 8 | beruwala
# Processing Record 31 of Set 8 | esfahan
# Processing Record 32 of Set 8 | kralendijk
# Processing Record 33 of Set 8 | simoes
# Processing Record 34 of Set 8 | mafinga
# Processing Record 35 of Set 8 | ibra
# Processing Record 36 of Set 8 | bela
# Processing Record 37 of Set 8 | abonnema
# Processing Record 38 of Set 8 | la palma
# Processing Record 39 of Set 8 | urumqi
# Processing Record 40 of Set 8 | calama
# Processing Record 41 of Set 8 | jizan
# Processing Record 42 of Set 8 | lloro
# Processing Record 43 of Set 8 | brae
# Processing Record 44 of Set 8 | corinto
# Processing Record 45 of Set 8 | pangnirtung
# Processing Record 46 of Set 8 | rambouillet
# Processing Record 47 of Set 8 | jacareacanga
# Processing Record 48 of Set 8 | kaya
# Processing Record 49 of Set 8 | luanda
# Processing Record 50 of Set 8 | havre-saint-pierre
# Processing Record 1 of Set 9 | harindanga
# Processing Record 2 of Set 9 | mansa
# Processing Record 3 of Set 9 | denia
# Processing Record 4 of Set 9 | rincon
# Processing Record 5 of Set 9 | los llanos de aridane
# Processing Record 6 of Set 9 | vangaindrano
# Processing Record 7 of Set 9 | ust-kalmanka
# Processing Record 8 of Set 9 | brownsville
# Processing Record 9 of Set 9 | soufriere
# Processing Record 10 of Set 9 | muli
# Processing Record 11 of Set 9 | cap malheureux
# Processing Record 12 of Set 9 | belyy yar
# Processing Record 13 of Set 9 | nacala
# Processing Record 14 of Set 9 | birnin kebbi
# Processing Record 15 of Set 9 | nova varos
# Processing Record 16 of Set 9 | kardla
# Processing Record 17 of Set 9 | chebenki
# Processing Record 18 of Set 9 | puerto ayacucho
# Processing Record 19 of Set 9 | zapolyarnyy
# Processing Record 20 of Set 9 | portobelo
# Processing Record 21 of Set 9 | ndioum
# Processing Record 22 of Set 9 | bilma
# Processing Record 23 of Set 9 | starychi
# Processing Record 24 of Set 9 | tipitapa
# Processing Record 25 of Set 9 | tucupita
# Processing Record 26 of Set 9 | carballo
# Processing Record 27 of Set 9 | clarence town
# Processing Record 28 of Set 9 | comodoro rivadavia
# Processing Record 29 of Set 9 | bereda
# Processing Record 30 of Set 9 | dingle
# Processing Record 31 of Set 9 | bay roberts
# Processing Record 32 of Set 9 | grand-lahou
# Processing Record 33 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 34 of Set 9 | lobez
# Processing Record 35 of Set 9 | sao felix do xingu
# Processing Record 36 of Set 9 | mangrol
# Processing Record 37 of Set 9 | limay
# Processing Record 38 of Set 9 | taoudenni
# Processing Record 39 of Set 9 | guiratinga
# Processing Record 40 of Set 9 | maniwaki
# Processing Record 41 of Set 9 | springbok
# Processing Record 42 of Set 9 | penzance
# Processing Record 43 of Set 9 | tucuman
# Processing Record 44 of Set 9 | isiro
# Processing Record 45 of Set 9 | severodvinsk
# Processing Record 46 of Set 9 | tromso
# Processing Record 47 of Set 9 | parabel
# Processing Record 48 of Set 9 | bagnols-sur-ceze
# Processing Record 49 of Set 9 | jaguarari
# Processing Record 50 of Set 9 | emba
# Processing Record 1 of Set 10 | mooi river
# City not found. Skipping...
# Processing Record 2 of Set 10 | requena
# Processing Record 3 of Set 10 | tupancireta
# Processing Record 4 of Set 10 | tessalit
# Processing Record 5 of Set 10 | lasa
# Processing Record 6 of Set 10 | borovoy
# Processing Record 7 of Set 10 | saint-joseph
# Processing Record 8 of Set 10 | mosquera
# Processing Record 9 of Set 10 | leh
# Processing Record 10 of Set 10 | boyle
# Processing Record 11 of Set 10 | waddan
# Processing Record 12 of Set 10 | vilhena
# Processing Record 13 of Set 10 | port-cartier
# Processing Record 14 of Set 10 | bhabua
# Processing Record 15 of Set 10 | san joaquin
# Processing Record 16 of Set 10 | parasia
# Processing Record 17 of Set 10 | tall kayf
# Processing Record 18 of Set 10 | stende
# Processing Record 19 of Set 10 | soria
# Processing Record 20 of Set 10 | kaniama
# Processing Record 21 of Set 10 | kishanpur
# Processing Record 22 of Set 10 | van
# Processing Record 23 of Set 10 | berdyuzhye
# City not found. Skipping...
# Processing Record 24 of Set 10 | balkhash
# Processing Record 25 of Set 10 | cambridge
# Processing Record 26 of Set 10 | libenge
# Processing Record 27 of Set 10 | vagur
# Processing Record 28 of Set 10 | mahibadhoo
# Processing Record 29 of Set 10 | tiruvottiyur
# City not found. Skipping...
# Processing Record 30 of Set 10 | russkaya polyana
# Processing Record 31 of Set 10 | ishim
# Processing Record 32 of Set 10 | nampula
# Processing Record 33 of Set 10 | yanam
# Processing Record 34 of Set 10 | moravsky beroun
# Processing Record 35 of Set 10 | great yarmouth
# Processing Record 36 of Set 10 | kebemer
# City not found. Skipping...
# Processing Record 37 of Set 10 | rosaryville
# Processing Record 38 of Set 10 | falkoping
# City not found. Skipping...
# Processing Record 39 of Set 10 | sinnamary
# Processing Record 40 of Set 10 | agropoli
# Processing Record 41 of Set 10 | tarko-sale
# Processing Record 42 of Set 10 | piritiba
# Processing Record 43 of Set 10 | watsa
# Processing Record 44 of Set 10 | pedernales
# Processing Record 45 of Set 10 | smolenskoye
# Processing Record 46 of Set 10 | najran
# Processing Record 47 of Set 10 | worcester
# Processing Record 48 of Set 10 | awjilah
# Processing Record 49 of Set 10 | cap-aux-meules
# Processing Record 50 of Set 10 | ust-tsilma
# Processing Record 1 of Set 11 | rudbar
# Processing Record 2 of Set 11 | manturovo
# Processing Record 3 of Set 11 | saint-louis
# Processing Record 4 of Set 11 | moose factory
# Processing Record 5 of Set 11 | iquique
# Processing Record 6 of Set 11 | wadi musa
# Processing Record 7 of Set 11 | oranjemund
# Processing Record 8 of Set 11 | les cayes
# Processing Record 9 of Set 11 | puerto quijarro
# Processing Record 10 of Set 11 | inta
# Processing Record 11 of Set 11 | chakwal
# Processing Record 12 of Set 11 | kautokeino
# Processing Record 13 of Set 11 | nara
# Processing Record 14 of Set 11 | puerto colombia
# Processing Record 15 of Set 11 | marrakesh
# Processing Record 16 of Set 11 | viedma
# Processing Record 17 of Set 11 | veraval
# Processing Record 18 of Set 11 | sharjah
# Processing Record 19 of Set 11 | hericourt
# Processing Record 20 of Set 11 | jamshedpur
# Processing Record 21 of Set 11 | plattsburgh
# Processing Record 22 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 23 of Set 11 | bridgetown
# Processing Record 24 of Set 11 | lefka
# Processing Record 25 of Set 11 | zaysan
# Processing Record 26 of Set 11 | skibotn
# Processing Record 27 of Set 11 | cozumel
# Processing Record 28 of Set 11 | kruisfontein
# Processing Record 29 of Set 11 | drezdenko
# Processing Record 30 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 31 of Set 11 | grand gaube
# Processing Record 32 of Set 11 | ilek
# Processing Record 33 of Set 11 | valkeakoski
# Processing Record 34 of Set 11 | villa de cura
# Processing Record 35 of Set 11 | korem
# Processing Record 36 of Set 11 | nizhniy baskunchak
# Processing Record 37 of Set 11 | apatity
# Processing Record 38 of Set 11 | yandyki
# Processing Record 39 of Set 11 | oussouye
# Processing Record 40 of Set 11 | pyryatyn
# Processing Record 41 of Set 11 | kerouane
# Processing Record 42 of Set 11 | upington
# Processing Record 43 of Set 11 | paita
# Processing Record 44 of Set 11 | turayf
# Processing Record 45 of Set 11 | selma
# Processing Record 46 of Set 11 | marawi
# Processing Record 47 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 48 of Set 11 | pokhara
# Processing Record 49 of Set 11 | purpe
# Processing Record 50 of Set 11 | yei
# Processing Record 1 of Set 12 | kalabo
# Processing Record 2 of Set 12 | svencionys
# Processing Record 3 of Set 12 | presidencia roque saenz pena
# Processing Record 4 of Set 12 | takoradi
# Processing Record 5 of Set 12 | luangwa
# Processing Record 6 of Set 12 | caetite
# Processing Record 7 of Set 12 | mendi
# Processing Record 8 of Set 12 | itarema
# Processing Record 9 of Set 12 | umm kaddadah
# Processing Record 10 of Set 12 | san ignacio
# Processing Record 11 of Set 12 | camacha
# Processing Record 12 of Set 12 | dudinka
# Processing Record 13 of Set 12 | casablanca
# Processing Record 14 of Set 12 | kaoma
# Processing Record 15 of Set 12 | mokrousovo
# Processing Record 16 of Set 12 | peniche
# Processing Record 17 of Set 12 | rio gallegos
# Processing Record 18 of Set 12 | grao mogol
# Processing Record 19 of Set 12 | constitucion
# Processing Record 20 of Set 12 | virginia beach
# Processing Record 21 of Set 12 | sapouy
# Processing Record 22 of Set 12 | amur
# Processing Record 23 of Set 12 | mongo
# Processing Record 24 of Set 12 | ushtobe
# Processing Record 25 of Set 12 | bandiagara
# Processing Record 26 of Set 12 | porto nacional
# Processing Record 27 of Set 12 | oneonta
# Processing Record 28 of Set 12 | pangody
# Processing Record 29 of Set 12 | aswan
# Processing Record 30 of Set 12 | mineros
# Processing Record 31 of Set 12 | nantucket
# Processing Record 32 of Set 12 | tshikapa
# Processing Record 33 of Set 12 | quepos
# Processing Record 34 of Set 12 | yalchiki
# City not found. Skipping...
# Processing Record 35 of Set 12 | carahue
# Processing Record 36 of Set 12 | itaituba
# Processing Record 37 of Set 12 | ankpa
# Processing Record 38 of Set 12 | swellendam
# Processing Record 39 of Set 12 | tatarbunary
# Processing Record 40 of Set 12 | goderich
# Processing Record 41 of Set 12 | karauzyak
# City not found. Skipping...
# Processing Record 42 of Set 12 | voznesenye
# Processing Record 43 of Set 12 | hukuntsi
# Processing Record 44 of Set 12 | marsabit
# Processing Record 45 of Set 12 | murgab
# Processing Record 46 of Set 12 | balakovo
# Processing Record 47 of Set 12 | macenta
# Processing Record 48 of Set 12 | matara
# Processing Record 49 of Set 12 | alexandria
# Processing Record 50 of Set 12 | mbandaka
# Processing Record 1 of Set 13 | banfora
# Processing Record 2 of Set 13 | batticaloa
# Processing Record 3 of Set 13 | gurjaani
# Processing Record 4 of Set 13 | mesyagutovo
# Processing Record 5 of Set 13 | piracaia
# Processing Record 6 of Set 13 | conselice
# Processing Record 7 of Set 13 | pitimbu
# Processing Record 8 of Set 13 | arona
# Processing Record 9 of Set 13 | el cortezo
# Processing Record 10 of Set 13 | pabrade
# Processing Record 11 of Set 13 | mgandu
# Processing Record 12 of Set 13 | tevriz
# Processing Record 13 of Set 13 | delta del tigre
# Processing Record 14 of Set 13 | kaduna
# Processing Record 15 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 16 of Set 13 | santa maria
# Processing Record 17 of Set 13 | porbandar
# Processing Record 18 of Set 13 | carauari
# Processing Record 19 of Set 13 | srisailam
# Processing Record 20 of Set 13 | atbasar
# Processing Record 21 of Set 13 | turia
# Processing Record 22 of Set 13 | akcakoca
# Processing Record 23 of Set 13 | terme
# Processing Record 24 of Set 13 | castro marim
# Processing Record 25 of Set 13 | lisakovsk
# Processing Record 26 of Set 13 | nsoko
# Processing Record 27 of Set 13 | pontes e lacerda
# Processing Record 28 of Set 13 | makamba
# Processing Record 29 of Set 13 | surt
# Processing Record 30 of Set 13 | oruro
# Processing Record 31 of Set 13 | trapani
# Processing Record 32 of Set 13 | barao de melgaco
# Processing Record 33 of Set 13 | canutama
# Processing Record 34 of Set 13 | amot
# Processing Record 35 of Set 13 | barraute
# Processing Record 36 of Set 13 | perpignan
# Processing Record 37 of Set 13 | wagar
# Processing Record 38 of Set 13 | alappuzha
# Processing Record 39 of Set 13 | nurota
# Processing Record 40 of Set 13 | nuuk
# Processing Record 41 of Set 13 | el alto
# Processing Record 42 of Set 13 | korla
# Processing Record 43 of Set 13 | asyut
# Processing Record 44 of Set 13 | kharp
# Processing Record 45 of Set 13 | avallon
# Processing Record 46 of Set 13 | madimba
# Processing Record 47 of Set 13 | aksehir
# Processing Record 48 of Set 13 | camocim
# Processing Record 49 of Set 13 | halifax
# Processing Record 50 of Set 13 | auburn
# Processing Record 1 of Set 14 | pimentel
# Processing Record 2 of Set 14 | uray
# Processing Record 3 of Set 14 | edea
# Processing Record 4 of Set 14 | larsnes
# Processing Record 5 of Set 14 | mayor pablo lagerenza
# Processing Record 6 of Set 14 | rawson
# Processing Record 7 of Set 14 | heinola
# Processing Record 8 of Set 14 | mindelo
# Processing Record 9 of Set 14 | cervo
# Processing Record 10 of Set 14 | aasiaat
# Processing Record 11 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 12 of Set 14 | kolobrzeg
# Processing Record 13 of Set 14 | sieradz
# Processing Record 14 of Set 14 | velez-malaga
# Processing Record 15 of Set 14 | oriximina
# Processing Record 16 of Set 14 | illapel
# Processing Record 17 of Set 14 | geresk
# City not found. Skipping...
# Processing Record 18 of Set 14 | nyandoma
# Processing Record 19 of Set 14 | quthing
# Processing Record 20 of Set 14 | abha
# Processing Record 21 of Set 14 | thinadhoo
# Processing Record 22 of Set 14 | kostomuksha
# Processing Record 23 of Set 14 | liwale
# Processing Record 24 of Set 14 | guaraciaba do norte
# Processing Record 25 of Set 14 | mufumbwe
# Processing Record 26 of Set 14 | kosh-agach
# Processing Record 27 of Set 14 | chingirlau
# Processing Record 28 of Set 14 | karkaralinsk
# City not found. Skipping...
# Processing Record 29 of Set 14 | road town
# Processing Record 30 of Set 14 | mudanya
# Processing Record 31 of Set 14 | port-gentil
# Processing Record 32 of Set 14 | mazamet
# Processing Record 33 of Set 14 | miraflores
# Processing Record 34 of Set 14 | suez
# Processing Record 35 of Set 14 | cape canaveral
# Processing Record 36 of Set 14 | gazojak
# Processing Record 37 of Set 14 | benton harbor
# Processing Record 38 of Set 14 | yangambi
# Processing Record 39 of Set 14 | numan
# Processing Record 40 of Set 14 | buenos aires
# Processing Record 41 of Set 14 | kudahuvadhoo
# Processing Record 42 of Set 14 | kapiri mposhi
# Processing Record 43 of Set 14 | gweta
# Processing Record 44 of Set 14 | bolobo
# Processing Record 45 of Set 14 | cururupu
# Processing Record 46 of Set 14 | amet
# Processing Record 47 of Set 14 | tiquisio
# Processing Record 48 of Set 14 | lages
# Processing Record 49 of Set 14 | muscat
# Processing Record 50 of Set 14 | kayerkan
# Processing Record 1 of Set 15 | vryburg
# Processing Record 2 of Set 15 | san juan
# Processing Record 3 of Set 15 | kerur
# Processing Record 4 of Set 15 | kidal
# Processing Record 5 of Set 15 | sohag
# Processing Record 6 of Set 15 | tiznit
# Processing Record 7 of Set 15 | laguna
# Processing Record 8 of Set 15 | chulym
# Processing Record 9 of Set 15 | horodyshche
# Processing Record 10 of Set 15 | malko tarnovo
# Processing Record 11 of Set 15 | samana
# Processing Record 12 of Set 15 | shenkursk
# Processing Record 13 of Set 15 | oranjestad
# Processing Record 14 of Set 15 | praia
# Processing Record 15 of Set 15 | deh rawud
# City not found. Skipping...
# Processing Record 16 of Set 15 | male
# Processing Record 17 of Set 15 | yabassi
# Processing Record 18 of Set 15 | farafangana
# Processing Record 19 of Set 15 | kyabe
# Processing Record 20 of Set 15 | dhidhdhoo
# Processing Record 21 of Set 15 | camapua
# Processing Record 22 of Set 15 | gurgan
# City not found. Skipping...
# Processing Record 23 of Set 15 | grand-santi
# Processing Record 24 of Set 15 | kazalinsk
# City not found. Skipping...
# Processing Record 25 of Set 15 | rolim de moura
# City not found. Skipping...
# Processing Record 26 of Set 15 | gasa
# Processing Record 27 of Set 15 | ugoofaaru
# Processing Record 28 of Set 15 | mazamari
# Processing Record 29 of Set 15 | kitgum
# Processing Record 30 of Set 15 | salta
# Processing Record 31 of Set 15 | guajara
# Processing Record 32 of Set 15 | bhuban
# Processing Record 33 of Set 15 | omboue
# Processing Record 34 of Set 15 | rio cuarto
# Processing Record 35 of Set 15 | nouakchott
# Processing Record 36 of Set 15 | ambodifototra
# City not found. Skipping...
# Processing Record 37 of Set 15 | kikwit
# Processing Record 38 of Set 15 | bury saint edmunds
# City not found. Skipping...
# Processing Record 39 of Set 15 | orcopampa
# Processing Record 40 of Set 15 | constantine
# Processing Record 41 of Set 15 | emborion
# Processing Record 42 of Set 15 | samfya
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add data to a new dataframe
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                         City Country      Lat      Lng  Max Temp  Humidity  \
# 0                  Cape Town      ZA -33.9258  18.4232     55.11        73
# 1                   Qaqortoq      GL  60.7167 -46.0333     32.50        64
# 2                    Iqaluit      CA  63.7506 -68.5145     31.69        88
# 3                   Hermanus      ZA -34.4187  19.2345     54.90        71
# 4                Port Alfred      ZA -33.5906  26.8910     56.64        72
# 5                    Sakakah      SA  29.9697  40.2064     65.82        37
# 6             Saint-Philippe      RE -21.3585  55.7679     74.75        82
# 7  Santa Isabel Do Rio Negro      BR  -0.4139 -65.0192     78.01        85
# 8                   Coquimbo      CL -29.9533 -71.3436     55.13        76
# 9                   Kurbnesh      AL  41.7797  20.0836     50.63        88
#
#    Cloudiness  Wind Speed       Description
# 0           1        6.60         clear sky
# 1          21        5.39        few clouds
# 2         100       17.00   overcast clouds
# 3          23        4.90        few clouds
# 4          27       13.65  scattered clouds
# 5           0        5.14         clear sky
# 6          40       13.56  scattered clouds
# 7          75        1.03     broken clouds
# 8           0        0.00         clear sky
# 9         100        9.93   overcast clouds

# %%
# Export the DataFr# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"

#Export the City_data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
